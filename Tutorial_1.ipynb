# %%
from os import ttyname
tu = (23, 'abc', 4.56, (2,3), 'def')
li = ["abc", 34, 4.34, 23]

st = "Hello World"
print(st)
st = 'Hello World'
print(st)
st = """This is a multi-line
string that uses triple quetes."""
print(st)

print(tu[1])
print(li[1])
st = "Hello World"
print(st[1])

t = (23, 'abc', 4.56)
print(t[1])
print(t[-3])

print(t[1:4])
print(t[1:-1])
print(t[1:-1:2])

print(t[:2])
print(t[2:])

print(t[:])

tt = [1, 2, 4, 5]
print(3 in tt)
print(4 in tt)
print(4 not in tt)
a = 'abcde'
print('c' in a)
print('cd' in a)
print('ac' in a)

print((1, 2, 3) + (4, 5, 6))
print([1, 2, 3] + [4, 5, 6])
print("Hello" + " " + "World")
# Out:
# Hello World
# Hello World
# This is a multi-line
# string that uses triple quetes.
# abc
# 34
# e
# abc
# 23
# ('abc', 4.56)
# ('abc',)
# ('abc',)
# (23, 'abc')
# (4.56,)
# (23, 'abc', 4.56)
# False
# True
# False
# True
# True
# False
# (1, 2, 3, 4, 5, 6)
# [1, 2, 3, 4, 5, 6]
# Hello World
