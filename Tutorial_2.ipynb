# %%
li = ['abc', 23, 4.34, 23]
li[1] = 45
print(li)

t = (23, 'abc', 4.56, (2,3), 'def')

li_ = [1, 11, 3, 4, 5]
li_.append('a')
print(li)

li_.insert(2, 'i')
print(li_)

li_.extend([9, 8, 7])
li_.append([10, 11 ,12])
print(li_)

li_2 = ['a', 'b', 'c', 'b']
print(li_2.index('b'))
print(li_2.count('b'))
li_2.remove('b')
print(li_2)

li_3 = [5, 2, 6, 8]

li_3.reverse()
print(li_3)

li_3.sort()
print(li_3)
# Out:
# ['abc', 45, 4.34, 23]
# ['abc', 45, 4.34, 23]
# [1, 11, 'i', 3, 4, 5, 'a']
# [1, 11, 'i', 3, 4, 5, 'a', 9, 8, 7, [10, 11, 12]]
# 1
# 2
# ['a', 'c', 'b']
# [8, 6, 2, 5]
# [2, 5, 6, 8]
