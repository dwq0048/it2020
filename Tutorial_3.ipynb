# %%
d = {'user':'bozo', 'pswd' : 1234, 'i' : 34}
print(d['user'])
print(d['pswd'])

d['user'] = 'clown'
print(d)

del d['user']
print(d)

d.clear()
print(d)

a=[1,2]
del a[1]
print(a)

d = {'user' : 'bozo', 'p' : 1234, 'i': 34}
print(d.keys())
print(d.values())
print(d.items())
# Out:
# bozo
# 1234
# {'user': 'clown', 'pswd': 1234, 'i': 34}
# {'pswd': 1234, 'i': 34}
# {}
# [1]
# dict_keys(['user', 'p', 'i'])
# dict_values(['bozo', 1234, 34])
# dict_items([('user', 'bozo'), ('p', 1234), ('i', 34)])
